# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os
import librosa
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')

# %%
main_path = "/kaggle/input"

paths = []
labels = []

for dirname, _, filenames in os.walk(main_path):
  for filename in filenames:
    paths.append(os.path.join(dirname, filename))
    label = filename.split('_')[-1]
    label = label.split(".")[0]
    labels.append(label.lower())

print("Dataset is loaded.")
# Out:
# Dataset is loaded.

# %%
# Creating Dataframe
data_df = pd.DataFrame()
data_df['speech_paths'] = paths
data_df['labels'] = labels
data_df['labels'] = data_df['labels'].astype('category')
data_df.head()
# Out:
#                                         speech_paths labels
# 0                      /kaggle/input/sad123/sad.opus    sad
# 1                   /kaggle/input/happyyy/happy.opus  happy
# 2  /kaggle/input/toronto-emotional-speech-set-tes...   fear
# 3  /kaggle/input/toronto-emotional-speech-set-tes...   fear
# 4  /kaggle/input/toronto-emotional-speech-set-tes...   fear

# %%
len(paths)
# Out:
# 5602

# %%
data_df['labels'].value_counts()
# Out:
# labels
# happy      801
# sad        801
# angry      800
# disgust    800
# fear       800
# neutral    800
# ps         800
# Name: count, dtype: int64

# %%
def waveplotting(data, sr, emotion):
  plt.figure(figsize=(10, 4))
  librosa.display.waveshow(data, sr=sr)
  plt.title(emotion, size=10)
  plt.show()

def spectrogram(data, sr, emotion):
  plt.figure(figsize=(10, 4))
  D = librosa.amplitude_to_db(abs(librosa.stft(data)))
  librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='hz')
  plt.colorbar(format='%+2.0f dB')
  plt.title(emotion, size=10)
  plt.show()

# %%
emotion = 'ps'
path = data_df['speech_paths'][data_df['labels'] == emotion].values[0]
data, sr = librosa.load(path)
waveplotting(data, sr, emotion)
spectrogram(data, sr, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'sad'
path = data_df['speech_paths'][data_df['labels'] == emotion].values[0]
data, sr = librosa.load(path)
waveplotting(data, sr, emotion)
spectrogram(data, sr, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'happy'
path = data_df['speech_paths'][data_df['labels'] == emotion].values[0]
data, sr = librosa.load(path)
waveplotting(data, sr, emotion)
spectrogram(data, sr, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'fear'
path = data_df['speech_paths'][data_df['labels'] == emotion].values[0]
data, sr = librosa.load(path)
waveplotting(data, sr, emotion)
spectrogram(data, sr, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'angry'
path = data_df['speech_paths'][data_df['labels'] == emotion].values[0]
data, sr = librosa.load(path)
waveplotting(data, sr, emotion)
spectrogram(data, sr, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'disgust'
path = data_df['speech_paths'][data_df['labels'] == emotion].values[0]
data, sr = librosa.load(path)
waveplotting(data, sr, emotion)
spectrogram(data, sr, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'neutral'
path = data_df['speech_paths'][data_df['labels'] == emotion].values[0]
data, sr = librosa.load(path)
waveplotting(data, sr, emotion)
spectrogram(data, sr, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def extract_mfcc(filename):
  data, sr = librosa.load(filename, duration=3, offset=0.5)
  mfccs = np.mean(librosa.feature.mfcc(y=data, sr=sr, n_mfcc=40).T, axis=0)
  return mfccs

extract_mfcc(path)
# Out:
# array([-5.2561853e+02,  7.2173584e+01,  3.0458908e+01,  2.2819047e+00,
#         7.9219284e+00,  1.3409611e+01,  3.4922962e+00, -1.2535165e+01,
#        -1.4074561e+01, -4.3916264e+00, -1.3104200e+01,  1.7670565e+00,
#        -6.1906023e+00,  3.7769110e+00,  1.1775386e+01,  3.3663719e+00,
#        -4.2563858e+00,  1.0509301e+01, -6.4693028e-01,  3.1845233e+00,
#         2.0781171e+00,  2.7246969e+00, -3.3753109e+00,  1.2149856e+00,
#        -5.2841105e+00,  1.5894290e+00, -1.0169716e+01,  8.1839198e-01,
#        -1.6448535e-01, -2.2671802e-01, -5.8958645e+00, -3.3275356e+00,
#        -6.4882321e+00,  4.1418386e+00,  1.1975582e+01,  2.1806164e+01,
#         3.4154102e+01,  3.1413456e+01,  2.0501556e+01,  1.4200143e+01],
#       dtype=float32)

# %%
X_mfcc = data_df['speech_paths'].apply(lambda x: extract_mfcc(x))
x_mfcc = np.array([x for x in X_mfcc])
x_mfcc.shape
# Out:
# (5602, 40)

# %%
# For LSTM model, expanding dimentions
x = np.expand_dims(x_mfcc, axis=2)
x.shape
# Out:
# (5602, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
y = encoder.fit_transform(np.array(data_df['labels']).reshape(-1,1)).toarray()
y.shape
# Out:
# (5602, 7)

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from keras.callbacks import EarlyStopping

model = Sequential()

model.add(LSTM(123, return_sequences=False, input_shape=(40, 1)))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(7, activation='softmax'))

model.compile(loss='categorical_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 123)               61500
#
#  dense (Dense)               (None, 64)                7936
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 7)                 231
#
# =================================================================
# Total params: 71747 (280.26 KB)
# Trainable params: 71747 (280.26 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(x, y, 
          epochs=100, 
          batch_size=512, 
          validation_split=0.2, 
          shuffle = True)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 6s 310ms/step - loss: 1.7701 - accuracy: 0.3452 - val_loss: 2.1954 - val_accuracy: 0.0134
# Epoch 2/100
# 9/9 [==============================] - 2s 226ms/step - loss: 1.4731 - accuracy: 0.5244 - val_loss: 2.0812 - val_accuracy: 0.1070
# Epoch 3/100
# 9/9 [==============================] - 2s 230ms/step - loss: 1.1208 - accuracy: 0.6405 - val_loss: 1.8882 - val_accuracy: 0.1079
# Epoch 4/100
# 9/9 [==============================] - 2s 220ms/step - loss: 0.8835 - accuracy: 0.6987 - val_loss: 1.6026 - val_accuracy: 0.1784
# Epoch 5/100
# 9/9 [==============================] - 2s 238ms/step - loss: 0.6698 - accuracy: 0.7668 - val_loss: 1.0429 - val_accuracy: 0.5772
# Epoch 6/100
# 9/9 [==============================] - 2s 230ms/step - loss: 0.4908 - accuracy: 0.8313 - val_loss: 0.7173 - val_accuracy: 0.6815
# Epoch 7/100
# 9/9 [==============================] - 2s 225ms/step - loss: 0.3789 - accuracy: 0.8697 - val_loss: 0.6730 - val_accuracy: 0.7716
# Epoch 8/100
# 9/9 [==============================] - 2s 221ms/step - loss: 0.3120 - accuracy: 0.8936 - val_loss: 0.4434 - val_accuracy: 0.8269
# Epoch 47/100
# 9/9 [==============================] - 2s 213ms/step - loss: 0.0238 - accuracy: 0.9942 - val_loss: 0.0191 - val_accuracy: 0.9955
# Epoch 48/100
# 9/9 [==============================] - 2s 213ms/step - loss: 0.0182 - accuracy: 0.9960 - val_loss: 0.0320 - val_accuracy: 0.9875
# Epoch 49/100
# 9/9 [==============================] - 2s 213ms/step - loss: 0.0222 - accuracy: 0.9935 - val_loss: 0.0178 - val_accuracy: 0.9938
# Epoch 50/100
# 9/9 [==============================] - 2s 227ms/step - loss: 0.0178 - accuracy: 0.9940 - val_loss: 0.0157 - val_accuracy: 0.9964
# Epoch 51/100
# 9/9 [==============================] - 2s 214ms/step - loss: 0.0216 - accuracy: 0.9946 - val_loss: 0.0172 - val_accuracy: 0.9955
# Epoch 52/100
# 9/9 [==============================] - 2s 221ms/step - loss: 0.0162 - accuracy: 0.9958 - val_loss: 0.0450 - val_accuracy: 0.9866
# Epoch 53/100
# 9/9 [==============================] - 2s 226ms/step - loss: 0.0266 - accuracy: 0.9911 - val_loss: 0.0403 - val_accuracy: 0.9884
# Epoch 54/100
# 9/9 [==============================] - 2s 217ms/step - loss: 0.0317 - accuracy: 0.9900 - val_loss: 0.0318 - val_accuracy: 0.9893
# Epoch 55/100
# 9/9 [==============================] - 2s 209ms/step - loss: 0.0255 - accuracy: 0.9926 - val_loss: 0.0406 - val_accuracy: 0.9875
# Epoch 56/100
# 9/9 [==============================] - 2s 216ms/step - loss: 0.0246 - accuracy: 0.9917 - val_loss: 0.0490 - val_accuracy: 0.9875
# Epoch 57/100
# 9/9 [==============================] - 2s 209ms/step - loss: 0.0216 - accuracy: 0.9931 - val_loss: 0.0312 - val_accuracy: 0.9875
# Epoch 58/100
# 9/9 [==============================] - 2s 217ms/step - loss: 0.0251 - accuracy: 0.9929 - val_loss: 0.0192 - val_accuracy: 0.9946
# Epoch 59/100
# 9/9 [==============================] - 2s 207ms/step - loss: 0.0363 - accuracy: 0.9906 - val_loss: 0.0371 - val_accuracy: 0.9875
# Epoch 60/100
# 9/9 [==============================] - 2s 223ms/step - loss: 0.0251 - accuracy: 0.9933 - val_loss: 0.0908 - val_accuracy: 0.9670
# Epoch 61/100
# 9/9 [==============================] - 2s 215ms/step - loss: 0.0250 - accuracy: 0.9929 - val_loss: 0.0140 - val_accuracy: 0.9946
# Epoch 62/100
# 9/9 [==============================] - 2s 213ms/step - loss: 0.0219 - accuracy: 0.9926 - val_loss: 0.0257 - val_accuracy: 0.9902
# Epoch 63/100
# 9/9 [==============================] - 2s 208ms/step - loss: 0.0214 - accuracy: 0.9931 - val_loss: 0.0724 - val_accuracy: 0.9768
# Epoch 64/100
# 9/9 [==============================] - 2s 215ms/step - loss: 0.0255 - accuracy: 0.9922 - val_loss: 0.0109 - val_accuracy: 0.9955
# Epoch 65/100
# 9/9 [==============================] - 2s 222ms/step - loss: 0.0264 - accuracy: 0.9926 - val_loss: 0.0331 - val_accuracy: 0.9920
# Epoch 66/100
# 9/9 [==============================] - 2s 224ms/step - loss: 0.0218 - accuracy: 0.9940 - val_loss: 0.0176 - val_accuracy: 0.9929
# Epoch 67/100
# 9/9 [==============================] - 2s 227ms/step - loss: 0.0223 - accuracy: 0.9946 - val_loss: 0.0091 - val_accuracy: 0.9964
# Epoch 68/100
# 9/9 [==============================] - 2s 223ms/step - loss: 0.0114 - accuracy: 0.9969 - val_loss: 0.0168 - val_accuracy: 0.9929
# Epoch 69/100
# 9/9 [==============================] - 2s 234ms/step - loss: 0.0117 - accuracy: 0.9973 - val_loss: 0.0152 - val_accuracy: 0.9946
# Epoch 70/100
# 9/9 [==============================] - 2s 245ms/step - loss: 0.0116 - accuracy: 0.9975 - val_loss: 0.0066 - val_accuracy: 0.9982
# Epoch 71/100
# 9/9 [==============================] - 2s 214ms/step - loss: 0.0095 - accuracy: 0.9978 - val_loss: 0.0063 - val_accuracy: 0.9982
# Epoch 72/100
# 9/9 [==============================] - 2s 214ms/step - loss: 0.0078 - accuracy: 0.9982 - val_loss: 0.0063 - val_accuracy: 0.9982
# Epoch 73/100
# 9/9 [==============================] - 2s 228ms/step - loss: 0.0065 - accuracy: 0.9984 - val_loss: 0.0061 - val_accuracy: 0.9991
# Epoch 74/100
# 9/9 [==============================] - 2s 212ms/step - loss: 0.0067 - accuracy: 0.9984 - val_loss: 0.0037 - val_accuracy: 0.9991
# Epoch 75/100
# 9/9 [==============================] - 2s 213ms/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.0052 - val_accuracy: 0.9991
# Epoch 76/100
# 9/9 [==============================] - 2s 218ms/step - loss: 0.0084 - accuracy: 0.9978 - val_loss: 0.0039 - val_accuracy: 0.9982
# Epoch 77/100
# 9/9 [==============================] - 2s 209ms/step - loss: 0.0071 - accuracy: 0.9987 - val_loss: 0.0055 - val_accuracy: 0.9982
# Epoch 78/100
# 9/9 [==============================] - 2s 215ms/step - loss: 0.0051 - accuracy: 0.9989 - val_loss: 0.0044 - val_accuracy: 0.9982
# Epoch 79/100
# 9/9 [==============================] - 2s 209ms/step - loss: 0.0065 - accuracy: 0.9984 - val_loss: 0.0044 - val_accuracy: 0.9982
# Epoch 80/100
# 9/9 [==============================] - 2s 207ms/step - loss: 0.0060 - accuracy: 0.9982 - val_loss: 0.0031 - val_accuracy: 0.9991
# Epoch 81/100
# 9/9 [==============================] - 2s 209ms/step - loss: 0.0071 - accuracy: 0.9987 - val_loss: 0.0024 - val_accuracy: 0.9991
# Epoch 82/100
# 9/9 [==============================] - 2s 209ms/step - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.0019 - val_accuracy: 0.9991
# Epoch 83/100
# 9/9 [==============================] - 2s 224ms/step - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.0027 - val_accuracy: 0.9991
# Epoch 84/100
# 9/9 [==============================] - 2s 221ms/step - loss: 0.0055 - accuracy: 0.9980 - val_loss: 0.0028 - val_accuracy: 0.9982
# Epoch 85/100
# 9/9 [==============================] - 2s 225ms/step - loss: 0.0064 - accuracy: 0.9980 - val_loss: 0.0025 - val_accuracy: 0.9991
# Epoch 86/100
# 9/9 [==============================] - 2s 221ms/step - loss: 0.0051 - accuracy: 0.9982 - val_loss: 0.0036 - val_accuracy: 0.9991
# Epoch 88/100
# 9/9 [==============================] - 2s 209ms/step - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.0017 - val_accuracy: 0.9991
# Epoch 89/100
# 9/9 [==============================] - 2s 209ms/step - loss: 0.0046 - accuracy: 0.9989 - val_loss: 0.0020 - val_accuracy: 0.9991
# Epoch 90/100
# 9/9 [==============================] - 2s 222ms/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.0029 - val_accuracy: 0.9991
# Epoch 91/100
# 9/9 [==============================] - 2s 229ms/step - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.0047 - val_accuracy: 0.9973
# Epoch 92/100
# 9/9 [==============================] - 2s 216ms/step - loss: 0.0071 - accuracy: 0.9980 - val_loss: 0.0030 - val_accuracy: 0.9982
# Epoch 93/100
# 9/9 [==============================] - 2s 230ms/step - loss: 0.0043 - accuracy: 0.9993 - val_loss: 0.0048 - val_accuracy: 0.9964
# Epoch 94/100
# 9/9 [==============================] - 2s 206ms/step - loss: 0.0045 - accuracy: 0.9989 - val_loss: 0.0026 - val_accuracy: 0.9991
# Epoch 95/100
# 9/9 [==============================] - 2s 211ms/step - loss: 0.0037 - accuracy: 0.9993 - val_loss: 0.0016 - val_accuracy: 0.9991
# Epoch 96/100
# 9/9 [==============================] - 2s 213ms/step - loss: 0.0034 - accuracy: 0.9993 - val_loss: 0.0081 - val_accuracy: 0.9964
# Epoch 97/100
# 9/9 [==============================] - 2s 217ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 8.2820e-04 - val_accuracy: 1.0000
# Epoch 98/100
# 9/9 [==============================] - 2s 227ms/step - loss: 0.0053 - accuracy: 0.9982 - val_loss: 9.6525e-04 - val_accuracy: 1.0000
# Epoch 99/100
# 9/9 [==============================] - 2s 215ms/step - loss: 0.0149 - accuracy: 0.9962 - val_loss: 0.0070 - val_accuracy: 0.9964
# Epoch 100/100
# 9/9 [==============================] - 2s 211ms/step - loss: 0.0124 - accuracy: 0.9962 - val_loss: 0.0150 - val_accuracy: 0.9929

# %%
from IPython.display import Audio

# Replace 'filename.mp3' with the actual filename from your dataset
file_path = '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_Fear/OAF_base_fear.wav'

Audio(file_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
test_path = '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_bar_ps.wav'  # Replace with the path to your test audio file
test_mfcc = extract_mfcc(test_path)  # Extract MFCC features for the test audio
test_input = np.expand_dims(test_mfcc, axis=0)  # Expand dimensions to match model input

# Predict emotions for test data
predictions = model.predict(test_input)  # Use the trained model to predict emotions

# Decode predictions to get the predicted emotion
predicted_emotion_index = np.argmax(predictions)  # Get index of highest probability
predicted_emotion = encoder.categories_[0][predicted_emotion_index]  # Decode index to emotion label

print("Predicted Emotion:", predicted_emotion)
# Out:
# 1/1 [==============================] - 0s 498ms/step
# Predicted Emotion: ps
